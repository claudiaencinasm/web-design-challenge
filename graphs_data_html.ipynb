# %%
import pandas as pd

# %%
data_df = pd.read_csv('resources/city_data.csv')

# %%
html_table = data_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Bethel</td>\n      <td>41.37</td>\n      <td>-73.41</td>\n      <td>296.48</td>\n      <td>88</td>\n      <td>75</td>\n      <td>3.10</td>\n      <td>US</td>\n      <td>1591915860</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Goderich</td>\n      <td>43.75</td>\n      <td>-81.72</td>\n      <td>293.71</td>\n      <td>62</td>\n      <td>0</td>\n      <td>7.15</td>\n      <td>CA</td>\n      <td>1591916401</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Hilo</td>\n      <td>19.73</td>\n      <td>-155.09</td>\n   
# ...

# %%
data_df.to_html("table.html")
